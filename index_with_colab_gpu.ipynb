# %% [markdown]
# # 🚀 Fast GPU Indexing for Multilingual RAG (English, Hindi, Marathi)
# This notebook indexes all 148,500+ passages across English, Hindi, and Marathi in **~60-90 seconds** using a free Google Colab GPU (T4/V100/A100).

# %%
# 1. Check GPU
# !nvidia-smi

# %%
# 2. Clone the RAGINGOA repository
# !git clone https://github.com/Anshsurana123/RAGINGOA.git
# %cd RAGINGOA

# %%
# 3. Install requirements with GPU acceleration
# !pip install -q faiss-gpu sentence-transformers onnxruntime

# %%
# 4. Run High-Speed GPU Indexing (~60-90 seconds)
# !python retrieval/build_indexes_gpu.py

# %%
# 5. Zip generated indexes for easy download
# !zip -r indexed_data.zip data/indexes/

from google.colab import files
files.download('indexed_data.zip')
